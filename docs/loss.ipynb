# %% [markdown]
# <div align="center">
#     <img src="zzzzimgs/delta_softmax.jpg" width="300">
#     <br>
#     <em></em>
# </div>
#
# <div align="center">
#     <img src="zzzzimgs/BCE.jpg" width="900">
#     <br>
#     <em></em>
# </div>
