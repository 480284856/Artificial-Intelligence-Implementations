# %% [markdown]
# 一个神经网络是由多个模块构成的。有些模块有参数，有些模块没有参数。
#
# 我们把这些有参数的模块提取出来（准确来说是引用这些参数，而不是复制），然后单独在优化器内进行梯度的参数更新。
#
# <div align="center">
#     <img src="zzzzimgs/design_of_optimizer.jpg" width="300">
#     <br>
#     <em></em>
# </div>
