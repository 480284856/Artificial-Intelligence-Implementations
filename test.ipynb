# %%
import torch

# %%
x = torch.tensor([1.,2.,2.])
x = torch.randn(10)
x = (x-x.mean())/x.std() * 4
print(x)
print(torch.nn.functional.sigmoid(x))
# Out:
# tensor([ 5.2824, -0.4911, -5.3966, -4.2780,  6.2871, -2.3950,  3.1271, -3.5110,
#          0.9278,  0.4474])
# tensor([0.9949, 0.3796, 0.0045, 0.0137, 0.9981, 0.0836, 0.9580, 0.0290, 0.7166,
#         0.6100])
